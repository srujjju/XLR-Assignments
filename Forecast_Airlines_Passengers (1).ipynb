# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-305a52ff-e17b-445e-81cf-df2655484f73" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-305a52ff-e17b-445e-81cf-df2655484f73">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

file =  pd.read_csv('Airlines+Data - Sheet1.csv')

# %%
file.head()
# Out:
#     Month  Passengers
# 0  Jan-95         112
# 1  Feb-95         118
# 2  Mar-95         132
# 3  Apr-95         129
# 4  May-95         121

# %%
# line plot
file.plot()
# Out:
# <Axes: >

# %%
file.hist()
# Out:
# array([[<Axes: title={'center': 'Passengers'}>]], dtype=object)

# %%
from matplotlib import pyplot
file.plot(kind='kde')
pyplot.show()

# %%
file.boxplot()
# Out:
# <Axes: >

# %%
import pandas as pd


data = {
    'Month': ['Jan-95', 'Feb-95', 'Mar-95', 'Apr-95', 'May-95', 'Jun-95', 'Jul-95', 'Aug-95', 'Sep-95', 'Oct-95', 'Nov-95', 'Dec-95', 'Jan-96', 'Feb-96', 'Mar-96', 'Apr-96', 'May-96', 'Jun-96', 'Jul-96', 'Aug-96', 'Sep-96', 'Oct-96', 'Nov-96', 'Dec-96', 'Jan-97', 'Feb-97', 'Mar-97', 'Apr-97', 'May-97', 'Jun-97', 'Jul-97', 'Aug-97', 'Sep-97', 'Oct-97', 'Nov-97', 'Dec-97', 'Jan-98', 'Feb-98', 'Mar-98', 'Apr-98', 'May-98', 'Jun-98', 'Jul-98', 'Aug-98', 'Sep-98', 'Oct-98', 'Nov-98', 'Dec-98', 'Jan-99', 'Feb-99', 'Mar-99', 'Apr-99', 'May-99', 'Jun-99', 'Jul-99', 'Aug-99', 'Sep-99', 'Oct-99', 'Nov-99', 'Dec-99', 'Jan-00', 'Feb-00', 'Mar-00', 'Apr-00', 'May-00', 'Jun-00', 'Jul-00', 'Aug-00', 'Sep-00', 'Oct-00', 'Nov-00', 'Dec-00', 'Jan-01', 'Feb-01', 'Mar-01', 'Apr-01', 'May-01', 'Jun-01', 'Jul-01', 'Aug-01', 'Sep-01', 'Oct-01', 'Nov-01', 'Dec-01', 'Jan-02', 'Feb-02', 'Mar-02', 'Apr-02', 'May-02', 'Jun-02', 'Jul-02', 'Aug-02', 'Sep-02', 'Oct-02', 'Nov-02', 'Dec-02'],
    'Passengers': [112, 118, 132, 129, 121, 135, 148, 148, 136, 119, 104, 118, 115, 126, 141, 135, 125, 149, 170, 170, 158, 133, 114, 140, 145, 150, 178, 163, 172, 178, 199, 199, 184, 162, 146, 166, 171, 180, 193, 181, 183, 218, 230, 242, 209, 191, 172, 194, 196, 196, 236, 235, 229, 243, 264, 272, 237, 211, 180, 201, 204, 188, 235, 227, 234, 264, 302, 293, 259, 229, 203, 229, 242, 233, 267, 269, 270, 315, 364, 347, 312, 274, 237, 278, 284, 277, 317, 313, 318, 374, 413, 405, 355, 306, 271, 306]
}

df = pd.DataFrame(data)

# Extract year and month from 'Month' column
df['Year'] = df['Month'].apply(lambda x: x.split('-')[1])
df['Month'] = df['Month'].apply(lambda x: x.split('-')[0])

# Pivot the DataFrame
file_pivot = df.pivot(index='Month', columns='Year', values='Passengers')

# Sort months in chronological order
months_order = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
df_pivot = file_pivot.reindex(months_order)

print(df_pivot)
# Out:
# Year    00   01   02   95   96   97   98   99
# Month
# Jan    204  242  284  112  115  145  171  196
# Feb    188  233  277  118  126  150  180  196
# Mar    235  267  317  132  141  178  193  236
# Apr    227  269  313  129  135  163  181  235
# May    234  270  318  121  125  172  183  229
# Jun    264  315  374  135  149  178  218  243
# Jul    302  364  413  148  170  199  230  264
# Aug    293  347  405  148  170  199  242  272
# Sep    259  312  355  136  158  184  209  237
# Oct    229  274  306  119  133  162  191  211
# Nov    203  237  271  104  114  146  172  180
# Dec    229  278  306  118  140  166  194  201

# %%
df_pivot.boxplot()
# Out:
# <Axes: >

# %%
import seaborn as sns

sns.heatmap(df_pivot, annot=True, cmap='coolwarm')
pyplot.show()

# %%
sns.lineplot(data=file, x="Month", y="Passengers")
pyplot.show()

# %%
df_pivot.shape
Train = df_pivot.head(147)
Test = df_pivot.tail(12)
df_pivot.head()
# Out:
# Year    00   01   02   95   96   97   98   99
# Month
# Jan    204  242  284  112  115  145  171  196
# Feb    188  233  277  118  126  150  180  196
# Mar    235  267  317  132  141  178  193  236
# Apr    227  269  313  129  135  163  181  235
# May    234  270  318  121  125  172  183  229

# %%
import statsmodels.formula.api as smf

# %%
# linear model
import pandas as pd
import statsmodels.formula.api as smf
from sklearn.metrics import mean_squared_error
import numpy as np


data = {
    'Month': ['Jan-95', 'Feb-95', 'Mar-95', 'Apr-95', 'May-95', 'Jun-95', 'Jul-95', 'Aug-95', 'Sep-95', 'Oct-95', 'Nov-95', 'Dec-95', 'Jan-96', 'Feb-96', 'Mar-96', 'Apr-96', 'May-96', 'Jun-96', 'Jul-96', 'Aug-96', 'Sep-96', 'Oct-96', 'Nov-96', 'Dec-96', 'Jan-97', 'Feb-97', 'Mar-97', 'Apr-97', 'May-97', 'Jun-97', 'Jul-97', 'Aug-97', 'Sep-97', 'Oct-97', 'Nov-97', 'Dec-97', 'Jan-98', 'Feb-98', 'Mar-98', 'Apr-98', 'May-98', 'Jun-98', 'Jul-98', 'Aug-98', 'Sep-98', 'Oct-98', 'Nov-98', 'Dec-98', 'Jan-99', 'Feb-99', 'Mar-99', 'Apr-99', 'May-99', 'Jun-99', 'Jul-99', 'Aug-99', 'Sep-99', 'Oct-99', 'Nov-99', 'Dec-99', 'Jan-00', 'Feb-00', 'Mar-00', 'Apr-00', 'May-00', 'Jun-00', 'Jul-00', 'Aug-00', 'Sep-00', 'Oct-00', 'Nov-00', 'Dec-00', 'Jan-01', 'Feb-01', 'Mar-01', 'Apr-01', 'May-01', 'Jun-01', 'Jul-01', 'Aug-01', 'Sep-01', 'Oct-01', 'Nov-01', 'Dec-01', 'Jan-02', 'Feb-02', 'Mar-02', 'Apr-02', 'May-02', 'Jun-02', 'Jul-02', 'Aug-02', 'Sep-02', 'Oct-02', 'Nov-02', 'Dec-02'],
    'Passengers': [112, 118, 132, 129, 121, 135, 148, 148, 136, 119, 104, 118, 115, 126, 141, 135, 125, 149, 170, 170, 158, 133, 114, 140, 145, 150, 178, 163, 172, 178, 199, 199, 184, 162, 146, 166, 171, 180, 193, 181, 183, 218, 230, 242, 209, 191, 172, 194, 196, 196, 236, 235, 229, 243, 264, 272, 237, 211, 180, 201, 204, 188, 235, 227, 234, 264, 302, 293, 259, 229, 203, 229, 242, 233, 267, 269, 270, 315, 364, 347, 312, 274, 237, 278, 284, 277, 317, 313, 318, 374, 413, 405, 355, 306, 271, 306]
}


df = pd.DataFrame(data)

# Extract year and month from 'Month' column
df['Year'] = df['Month'].str[-2:]
df['Month'] = df['Month'].str[:-3]

# Convert 'Year' and 'Month' columns to integers
df['Year'] = df['Year'].astype(int)
df['Month'] = pd.to_datetime(df['Month'], format='%b').dt.month

# Define the model formula
formula = 'Passengers ~ C(Year) + C(Month)'

# Fit the model
model = smf.ols(formula=formula, data=df).fit()


# Print model summary
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:             Passengers   R-squared:                       0.970
# Model:                            OLS   Adj. R-squared:                  0.963
# Method:                 Least Squares   F-statistic:                     137.0
# Date:                Wed, 06 Mar 2024   Prob (F-statistic):           7.50e-51
# Time:                        05:46:03   Log-Likelihood:                -378.29
# No. Observations:                  96   AIC:                             794.6
# Df Residuals:                      77   BIC:                             843.3
# Df Model:                          18
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Intercept        208.8333      6.184     33.773      0.000     196.520     221.146
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.holtwinters import ExponentialSmoothing
from sklearn.metrics import mean_squared_error


data = {
    'Month': ['Jan-95', 'Feb-95', 'Mar-95', 'Apr-95', 'May-95', 'Jun-95', 'Jul-95', 'Aug-95', 'Sep-95', 'Oct-95', 'Nov-95', 'Dec-95', 'Jan-96', 'Feb-96', 'Mar-96', 'Apr-96', 'May-96', 'Jun-96', 'Jul-96', 'Aug-96', 'Sep-96', 'Oct-96', 'Nov-96', 'Dec-96', 'Jan-97', 'Feb-97', 'Mar-97', 'Apr-97', 'May-97', 'Jun-97', 'Jul-97', 'Aug-97', 'Sep-97', 'Oct-97', 'Nov-97', 'Dec-97', 'Jan-98', 'Feb-98', 'Mar-98', 'Apr-98', 'May-98', 'Jun-98', 'Jul-98', 'Aug-98', 'Sep-98', 'Oct-98', 'Nov-98', 'Dec-98', 'Jan-99', 'Feb-99', 'Mar-99', 'Apr-99', 'May-99', 'Jun-99', 'Jul-99', 'Aug-99', 'Sep-99', 'Oct-99', 'Nov-99', 'Dec-99', 'Jan-00', 'Feb-00', 'Mar-00', 'Apr-00', 'May-00', 'Jun-00', 'Jul-00', 'Aug-00', 'Sep-00', 'Oct-00', 'Nov-00', 'Dec-00', 'Jan-01', 'Feb-01', 'Mar-01', 'Apr-01', 'May-01', 'Jun-01', 'Jul-01', 'Aug-01', 'Sep-01', 'Oct-01', 'Nov-01', 'Dec-01', 'Jan-02', 'Feb-02', 'Mar-02', 'Apr-02', 'May-02', 'Jun-02', 'Jul-02', 'Aug-02', 'Sep-02', 'Oct-02', 'Nov-02', 'Dec-02'],
    'Passengers': [112, 118, 132, 129, 121, 135, 148, 148, 136, 119, 104, 118, 115, 126, 141, 135, 125, 149, 170, 170, 158, 133, 114, 140, 145, 150, 178, 163, 172, 178, 199, 199, 184, 162, 146, 166, 171, 180, 193, 181, 183, 218, 230, 242, 209, 191, 172, 194, 196, 196, 236, 235, 229, 243, 264, 272, 237, 211, 180, 201, 204, 188, 235, 227, 234, 264, 302, 293, 259, 229, 203, 229, 242, 233, 267, 269, 270, 315, 364, 347, 312, 274, 237, 278, 284, 277, 317, 313, 318, 374, 413, 405, 355, 306, 271, 306]
}


df = pd.DataFrame(data)


df['Year'] = df['Month'].str[-2:]
df['Month'] = df['Month'].str[:-3]


df['Year'] = df['Year'].astype(int)
df['Month'] = pd.to_datetime(df['Month'], format='%b').dt.month


ts = pd.Series(df['Passengers'].values, index=pd.date_range(start='1995-01-01', periods=len(df), freq='M'))


model = ExponentialSmoothing(ts, seasonal_periods=12, trend='add', seasonal='add').fit()


predictions = model.forecast(len(df))

# Calculate RMSE
rmse = np.sqrt(mean_squared_error(ts, predictions))
print("RMSE:", rmse)

# Plot the data and the forecast
plt.figure(figsize=(10, 6))
plt.plot(ts, label='Actual')
plt.plot(predictions, label='Forecast')
plt.title('Exponential Smoothing Forecast')
plt.xlabel('Year')
plt.ylabel('Passengers')
plt.legend()
plt.show()
# Print model summary
print(model.summary())
# Out:
# RMSE: 243.4249609903569
#                        ExponentialSmoothing Model Results
# ...
# Dep. Variable:                     None   No. Observations:                   96
# Model:             ExponentialSmoothing   SSE                           9767.248
# Optimized:                         True   AIC                            475.754
# Trend:                         Additive   BIC                            516.784
# Seasonal:                      Additive   AICC                           484.638
# Seasonal Periods:                    12   Date:                 Wed, 06 Mar 2024
# Box-Cox:                          False   Time:                         05:44:30
# Box-Cox Coeff.:                    None
# ...
#                           coeff                 code              optimized
# ---------------------------------------------------------------------------------
# smoothing_level               0.2546480                alpha                 True
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.metrics import mean_squared_error


data = {
    'Month': ['Jan-95', 'Feb-95', 'Mar-95', 'Apr-95', 'May-95', 'Jun-95', 'Jul-95', 'Aug-95', 'Sep-95', 'Oct-95', 'Nov-95', 'Dec-95', 'Jan-96', 'Feb-96', 'Mar-96', 'Apr-96', 'May-96', 'Jun-96', 'Jul-96', 'Aug-96', 'Sep-96', 'Oct-96', 'Nov-96', 'Dec-96', 'Jan-97', 'Feb-97', 'Mar-97', 'Apr-97', 'May-97', 'Jun-97', 'Jul-97', 'Aug-97', 'Sep-97', 'Oct-97', 'Nov-97', 'Dec-97', 'Jan-98', 'Feb-98', 'Mar-98', 'Apr-98', 'May-98', 'Jun-98', 'Jul-98', 'Aug-98', 'Sep-98', 'Oct-98', 'Nov-98', 'Dec-98', 'Jan-99', 'Feb-99', 'Mar-99', 'Apr-99', 'May-99', 'Jun-99', 'Jul-99', 'Aug-99', 'Sep-99', 'Oct-99', 'Nov-99', 'Dec-99', 'Jan-00', 'Feb-00', 'Mar-00', 'Apr-00', 'May-00', 'Jun-00', 'Jul-00', 'Aug-00', 'Sep-00', 'Oct-00', 'Nov-00', 'Dec-00', 'Jan-01', 'Feb-01', 'Mar-01', 'Apr-01', 'May-01', 'Jun-01', 'Jul-01', 'Aug-01', 'Sep-01', 'Oct-01', 'Nov-01', 'Dec-01', 'Jan-02', 'Feb-02', 'Mar-02', 'Apr-02', 'May-02', 'Jun-02', 'Jul-02', 'Aug-02', 'Sep-02', 'Oct-02', 'Nov-02', 'Dec-02'],
    'Passengers': [112, 118, 132, 129, 121, 135, 148, 148, 136, 119, 104, 118, 115, 126, 141, 135, 125, 149, 170, 170, 158, 133, 114, 140, 145, 150, 178, 163, 172, 178, 199, 199, 184, 162, 146, 166, 171, 180, 193, 181, 183, 218, 230, 242, 209, 191, 172, 194, 196, 196, 236, 235, 229, 243, 264, 272, 237, 211, 180, 201, 204, 188, 235, 227, 234, 264, 302, 293, 259, 229, 203, 229, 242, 233, 267, 269, 270, 315, 364, 347, 312, 274, 237, 278, 284, 277, 317, 313, 318, 374, 413, 405, 355, 306, 271, 306]
}

df = pd.DataFrame(data)


df['Year'] = df['Month'].str[-2:]
df['Month'] = df['Month'].str[:-3]

df['Year'] = df['Year'].astype(int)
df['Month'] = pd.to_datetime(df['Month'], format='%b').dt.month


poly = PolynomialFeatures(degree=2)
X_poly = poly.fit_transform(df[['Year', 'Month']])


model = LinearRegression()
model.fit(X_poly, df['Passengers'])


predictions = model.predict(X_poly)

# Calculate RMSE
rmse = np.sqrt(mean_squared_error(df['Passengers'], predictions))
print("RMSE:", rmse)

# Plot the data and the forecast
plt.figure(figsize=(10, 6))
plt.plot(df.index, df['Passengers'], label='Actual')
plt.plot(df.index, predictions, label='Forecast')
plt.title('Quadratic Regression Forecast')
plt.xlabel('Time')
plt.ylabel('Passengers')
plt.legend()
plt.show()
# Out:
# RMSE: 39.14944325378842

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm
from sklearn.metrics import mean_squared_error


data = {
    'Month': ['Jan-95', 'Feb-95', 'Mar-95', 'Apr-95', 'May-95', 'Jun-95', 'Jul-95', 'Aug-95', 'Sep-95', 'Oct-95', 'Nov-95', 'Dec-95', 'Jan-96', 'Feb-96', 'Mar-96', 'Apr-96', 'May-96', 'Jun-96', 'Jul-96', 'Aug-96', 'Sep-96', 'Oct-96', 'Nov-96', 'Dec-96', 'Jan-97', 'Feb-97', 'Mar-97', 'Apr-97', 'May-97', 'Jun-97', 'Jul-97', 'Aug-97', 'Sep-97', 'Oct-97', 'Nov-97', 'Dec-97', 'Jan-98', 'Feb-98', 'Mar-98', 'Apr-98', 'May-98', 'Jun-98', 'Jul-98', 'Aug-98', 'Sep-98', 'Oct-98', 'Nov-98', 'Dec-98', 'Jan-99', 'Feb-99', 'Mar-99', 'Apr-99', 'May-99', 'Jun-99', 'Jul-99', 'Aug-99', 'Sep-99', 'Oct-99', 'Nov-99', 'Dec-99', 'Jan-00', 'Feb-00', 'Mar-00', 'Apr-00', 'May-00', 'Jun-00', 'Jul-00', 'Aug-00', 'Sep-00', 'Oct-00', 'Nov-00', 'Dec-00', 'Jan-01', 'Feb-01', 'Mar-01', 'Apr-01', 'May-01', 'Jun-01', 'Jul-01', 'Aug-01', 'Sep-01', 'Oct-01', 'Nov-01', 'Dec-01', 'Jan-02', 'Feb-02', 'Mar-02', 'Apr-02', 'May-02', 'Jun-02', 'Jul-02', 'Aug-02', 'Sep-02', 'Oct-02', 'Nov-02', 'Dec-02'],
    'Passengers': [112, 118, 132, 129, 121, 135, 148, 148, 136, 119, 104, 118, 115, 126, 141, 135, 125, 149, 170, 170, 158, 133, 114, 140, 145, 150, 178, 163, 172, 178, 199, 199, 184, 162, 146, 166, 171, 180, 193, 181, 183, 218, 230, 242, 209, 191, 172, 194, 196, 196, 236, 235, 229, 243, 264, 272, 237, 211, 180, 201, 204, 188, 235, 227, 234, 264, 302, 293, 259, 229, 203, 229, 242, 233, 267, 269, 270, 315, 364, 347, 312, 274, 237, 278, 284, 277, 317, 313, 318, 374, 413, 405, 355, 306, 271, 306]
}

df = pd.DataFrame(data)


df['Year'] = df['Month'].str[-2:]
df['Month'] = df['Month'].str[:-3]

df['Year'] = df['Year'].astype(int)
df['Month'] = pd.to_datetime(df['Month'], format='%b').dt.month

X = sm.add_constant(df[['Year', 'Month']])
y = df['Passengers']
model = sm.OLS(y, X).fit()


predictions = model.predict(X)

# Calculate RMSE
rmse = np.sqrt(mean_squared_error(y, predictions))
print("RMSE:", rmse)

# Plot the data and the forecast
plt.figure(figsize=(10, 6))
plt.plot(df.index, df['Passengers'], label='Actual')
plt.plot(df.index, predictions, label='Forecast')
plt.title('Linear Regression Forecast')
plt.xlabel('Time')
plt.ylabel('Passengers')
plt.legend()
plt.show()
# Out:
# RMSE: 47.45973984292378
